# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(135deg, #3a0ca3, #7209b7 30%, #f72585 80%);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Import Libraries
#     </h1>
# </div>

# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))

from config.spark_config import SparkConfig
from utils.logger import LoggerFactory
from config.io_config import *
from app.platform_app import PlatformApp
from transformation.bronze_ingestion import *

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Bronze</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(135deg, #3a0ca3, #7209b7 30%, #f72585 80%);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Bronze
#     </h1>
# </div>

# %%
# Initialize shared logger (all logs in this run go to the same file: etl_<run_id>.log)
logger = LoggerFactory.setup_logger(name="ETL", log_dir=LOG_DIR)

# Create Spark session with logging enabled (for tracing Spark-related operations)
spark = SparkConfig.create_spark(app_name="Paypal Analytic", logger=logger, use_databricks=True)

# Initialize main application with Spark and logger (used across ETL pipeline)
app = PlatformApp(spark=spark, logger=logger, catalog_name="paypal_analytic")
# Out:
# 2026-04-01 19:35:39 | INFO     | ETL | logger.py:113 | Logger initialized | level=DEBUG | file=C:/01_Data/05-data-engineer-bootcamp/03_paypal_databricks/logs\etl_20260401_193104_713773.log
# 2026-04-01 19:35:40 | INFO     | ETL | spark_config.py:89 | Connected to Databricks via Spark Connect.
# 2026-04-01 19:35:40 | INFO     | ETL | platform_app.py:44 | Initializing Data Platform...
# 2026-04-01 19:35:40 | INFO     | ETL | platform_app.py:50 | Spark session initialized

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Bronze</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(135deg, #3a0ca3, #7209b7 30%, #f72585 80%);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Bronze
#     </h1>
# </div>

# %%
# Bronze Ingestion
upload_file_to_bronze(spark=spark, logger=logger, list_entity=app.DEFAULT_ENTITIES,
                      path_data=S3_BASE_PATH, path_cp=CP_PATH_BRONZE,
                      name_catalog=app.catalog_name)
# Out:
# 2026-04-01 19:35:44 | INFO     | ETL | bronze_ingestion.py:59 | Ingesting data into Bronze layer...
# 2026-04-01 19:35:44 | INFO     | ETL | bronze_ingestion.py:66 | Starting Bronze ingestion for entity: Transactions
# 2026-04-01 19:35:44 | INFO     | ETL | bronze_ingestion.py:74 | Uploading file: s3://01-paypal-analytics/transactions
# 2026-04-01 19:35:59 | INFO     | ETL | bronze_ingestion.py:94 | Transactions: Schema inferred successfully
# 2026-04-01 19:36:31 | INFO     | ETL | bronze_ingestion.py:147 | Completed Bronze ingestion for entity: Transactions
# +-----------------+----------------------+------------------------------+------------------------------+----------------------------------------------+------------------+-------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+----------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+--------------+------------------------------+----------+----+-----------------------+----------------+---------+----------------------+
# |transaction_id   |transaction_event_code|transaction_initiation_date   |transaction_updated_date      |transaction_amount                            |transaction_status|transaction_subject                                                                                                            |ending_balance                                |available_balance                             |protection_eligibility|payer_info                                                                                                                                                                                                                                                             |shipping_info                                                                                                                                             |cart_info                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |store_info|auction_info|incentive_info|elton_created_at              |dt        |hour|read_timestamp         |file_name       |file_size|file_modification_time|
# +-----------------+----------------------+------------------------------+------------------------------+----------------------------------------------+------------------+-------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+----------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+--------------+------------------------------+----------+----+-----------------------+----------------+---------+----------------------+
# |8F987681LS7188052|T0006                 |2023-10-01 01:02:44.000000 UTC|2023-10-01 01:02:44.000000 UTC|{"currency_code": "USD", "value": "160.04"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "17286.58"} |{"currency_code": "USD", "value": "17286.58"} |01                    |{"account_id": "RW7EKEG97GXZG", "email_address": "erniefishingboat@hotmail.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"alternate_full_name": "The Blacksmith Shop"}, "country_code": "US"}                                                       |{"name": "Jackson Ernest", "address": {"line1": "1073 Belton Rd", "city": "Ripley", "country_code": "US", "postal_code": "38063"}}                        |{"item_details": [{"item_name": "Buy 3 Get 2 Free (200 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "149.97"}, "item_amount": {"currency_code": "USD", "value": "149.97"}, "total_item_amount": {"currency_code": "USD", "value": "149.97"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}, {"item_name": "Expedited Shipping", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "9.97"}, "item_amount": {"currency_code": "USD", "value": "9.97"}, "total_item_amount": {"currency_code": "USD", "value": "9.97"}}]}                      |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |95328985WP2643805|T0006                 |2023-10-01 01:17:17.000000 UTC|2023-10-01 01:17:17.000000 UTC|{"currency_code": "USD", "value": "99.95"}    |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "17381.83"} |{"currency_code": "USD", "value": "17381.83"} |01                    |{"account_id": "DL2W39YNL9TAA", "email_address": "randallmontel@yahoo.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"given_name": "Montel", "surname": "Randall", "alternate_full_name": "Montel Randall"}, "country_code": "US"}                   |{"name": "Montel ", "address": {"line1": "215 school st ", "city": "Millington", "country_code": "US", "postal_code": "21651"}}                           |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "89.98"}, "item_amount": {"currency_code": "USD", "value": "89.98"}, "total_item_amount": {"currency_code": "USD", "value": "89.98"}}, {"item_name": "Expedited Shipping", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "9.97"}, "item_amount": {"currency_code": "USD", "value": "9.97"}, "total_item_amount": {"currency_code": "USD", "value": "9.97"}}]}                                                                                                                                                                                                                                                                    |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |9P744271DM206464L|T1106                 |2023-10-01 01:49:31.000000 UTC|2023-10-01 01:49:31.000000 UTC|{"currency_code": "USD", "value": "-0.01"}    |S                 |69.94 USD; 2023-09-30 Credit has been processed and claim is now closed. Please refer Dispute ID PP-R-SJR-497568989. Thank you.|{"currency_code": "USD", "value": "17538.97"} |{"currency_code": "USD", "value": "17538.97"} |02                    |{"account_id": "QDHTZQ7XBEW6L", "email_address": "davidbeatrize@yahoo.com", "address_status": "N", "payer_status": "N", "payer_name": {"given_name": "victor", "surname": "meza", "alternate_full_name": "victor meza"}, "country_code": "US"}                         |{"name": "victor, meza"}                                                                                                                                  |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |8V050773ME0194317|T1111                 |2023-09-21 01:42:45.000000 UTC|2023-10-01 01:49:31.000000 UTC|{"currency_code": "USD", "value": "0.01"}     |D                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "17538.98"} |{"currency_code": "USD", "value": "17538.98"} |02                    |{"account_id": "QDHTZQ7XBEW6L", "email_address": "davidbeatrize@yahoo.com", "address_status": "N", "payer_status": "N", "payer_name": {"given_name": "victor", "surname": "meza", "alternate_full_name": "victor meza"}, "country_code": "US"}                         |{"name": "victor, meza"}                                                                                                                                  |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |1MY863496S997480P|T0006                 |2023-10-01 02:25:23.000000 UTC|2023-10-01 02:25:23.000000 UTC|{"currency_code": "USD", "value": "99.90"}    |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "18041.02"} |{"currency_code": "USD", "value": "18041.02"} |01                    |{"account_id": "RXHR62GNLVREC", "email_address": "dwyerandrew33@gmail.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"given_name": "Andrew", "surname": "Dwyer", "middle_name": "And", "alternate_full_name": "Andrew Dwyer"}, "country_code": "CA"} |{"name": "Andrew Dwyer", "address": {"line1": "22 rue Marie-C\u00e9cile ", "city": "Levis ", "country_code": "CA", "postal_code": "G6J 1L6"}}             |{"item_details": [{"item_name": "Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "54.96"}, "item_amount": {"currency_code": "USD", "value": "54.96"}, "total_item_amount": {"currency_code": "USD", "value": "54.96"}}, {"item_name": "Expedited Shipping", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "9.97"}, "item_amount": {"currency_code": "USD", "value": "9.97"}, "total_item_amount": {"currency_code": "USD", "value": "9.97"}}, {"item_name": "Gift For Loved One - Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "34.97"}, "item_amount": {"currency_code": "USD", "value": "34.97"}, "total_item_amount": {"currency_code": "USD", "value": "34.97"}}]}    |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |9SH54255AH4669625|T0006                 |2023-10-01 04:39:38.000000 UTC|2023-10-01 04:39:38.000000 UTC|{"currency_code": "USD", "value": "134.95"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "20123.63"} |{"currency_code": "USD", "value": "20123.63"} |01                    |{"account_id": "GX48VP6V5YQ4E", "email_address": "greenideas4ever@gmail.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"given_name": "Brian S", "surname": "Charles", "alternate_full_name": "Brian S Charles"}, "country_code": "US"}               |{"name": "Brian Charles", "address": {"line1": "15501 N Pennsylvania Ave, Apartment 205", "city": "Edmond", "country_code": "US", "postal_code": "73013"}}|{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "99.98"}, "item_amount": {"currency_code": "USD", "value": "99.98"}, "total_item_amount": {"currency_code": "USD", "value": "99.98"}}, {"item_name": "Gift For Loved One - Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "34.97"}, "item_amount": {"currency_code": "USD", "value": "34.97"}, "total_item_amount": {"currency_code": "USD", "value": "34.97"}}]}                                                                                                                                                                                                                                           |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |79F81216FW2838701|T0006                 |2023-10-01 07:17:58.000000 UTC|2023-10-01 07:17:58.000000 UTC|{"currency_code": "USD", "value": "90.08"}    |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "21138.77"} |{"currency_code": "USD", "value": "21138.77"} |01                    |{"account_id": "JG79BK9Y98RU8", "email_address": "toddspencer3@gmail.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"alternate_full_name": "Spencer's Plumbing"}, "country_code": "US"}                                                              |{"name": "Todd Spencer", "address": {"line1": "127 kanoelani St ", "city": "Hilo", "country_code": "US", "postal_code": "96720"}}                         |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "89.98"}, "item_amount": {"currency_code": "USD", "value": "89.98"}, "total_item_amount": {"currency_code": "USD", "value": "89.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}]}                                                                                                                                                                                                                                                                            |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |9B05674238648372D|T0006                 |2023-10-01 09:37:19.000000 UTC|2023-10-01 09:37:19.000000 UTC|{"currency_code": "USD", "value": "159.94"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "21629.82"} |{"currency_code": "USD", "value": "21629.82"} |01                    |{"account_id": "PEB95LDQUSJVY", "email_address": "prenevey@me.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"alternate_full_name": "Pierre H. Renevey"}, "country_code": "CH"}                                                                      |{"name": "Pierre Henri Renevey", "address": {"line1": "Route de la Verna 11", "city": "Corminboeuf", "country_code": "CH", "postal_code": "1720"}}        |{"item_details": [{"item_name": "Buy 3 Get 2 Free (200 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "149.97"}, "item_amount": {"currency_code": "USD", "value": "149.97"}, "total_item_amount": {"currency_code": "USD", "value": "149.97"}}, {"item_name": "Expedited Shipping", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "9.97"}, "item_amount": {"currency_code": "USD", "value": "9.97"}, "total_item_amount": {"currency_code": "USD", "value": "9.97"}}]}                                                                                                                                                                                                                                                                 |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |6WP15967VX679962R|T1503                 |2023-10-01 10:19:03.000000 UTC|2023-10-01 10:19:03.000000 UTC|{"currency_code": "USD", "value": "-21001.00"}|S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "819.48"}   |{"currency_code": "USD", "value": "819.48"}   |02                    |{"address_status": "N", "payer_name": {}}                                                                                                                                                                                                                              |{}                                                                                                                                                        |{}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |5PE47498L7117860E|T0001                 |2023-10-01 10:19:04.000000 UTC|2023-10-01 10:19:04.000000 UTC|{"currency_code": "USD", "value": "-21000.00"}|S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "-20181.52"}|{"currency_code": "USD", "value": "-20181.52"}|02                    |{"account_id": "YGWJZKYPUPJL2", "email_address": "doantantai69@gmail.com", "address_status": "N", "payer_status": "Y", "payer_name": {"alternate_full_name": "Bui Minh Thao"}, "country_code": "VN"}                                                                   |{"name": "CONG TOAN, MAI"}                                                                                                                                |{}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |1R778856E0108364W|T1105                 |2023-10-01 10:19:04.000000 UTC|2023-10-01 10:19:04.000000 UTC|{"currency_code": "USD", "value": "21001.00"} |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "819.48"}   |{"currency_code": "USD", "value": "819.48"}   |02                    |{"address_status": "N", "payer_name": {}}                                                                                                                                                                                                                              |{}                                                                                                                                                        |{}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |3RR902821H120603H|T1110                 |2023-10-01 10:27:38.000000 UTC|2023-10-01 10:27:38.000000 UTC|{"currency_code": "USD", "value": "-104.81"}  |P                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "714.67"}   |{"currency_code": "USD", "value": "714.67"}   |02                    |{"account_id": "3E74929MJVR3Y", "email_address": "oliviersambs@gmail.com", "address_status": "N", "payer_status": "N", "payer_name": {"given_name": "olivier", "surname": "samba", "alternate_full_name": "olivier samba"}, "country_code": "US"}                      |{"name": "olivier, samba"}                                                                                                                                |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}, {"item_name": "Expedited Shipping", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |5A315850GX9847623|T0006                 |2023-10-01 11:32:04.000000 UTC|2023-10-01 11:32:04.000000 UTC|{"currency_code": "USD", "value": "100.05"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "1519.88"}  |{"currency_code": "USD", "value": "1519.88"}  |01                    |{"account_id": "7HL5J3Y2VJM6C", "email_address": "jkiller64@yahoo.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"given_name": "john", "surname": "killinger", "alternate_full_name": "john killinger"}, "country_code": "US"}                       |{"name": "John Killinger", "address": {"line1": "151 avon village  dr", "city": "avon", "country_code": "US", "postal_code": "46123"}}                    |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "89.98"}, "item_amount": {"currency_code": "USD", "value": "89.98"}, "total_item_amount": {"currency_code": "USD", "value": "89.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}, {"item_name": "Expedited Shipping", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "9.97"}, "item_amount": {"currency_code": "USD", "value": "9.97"}, "total_item_amount": {"currency_code": "USD", "value": "9.97"}}]}                         |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |1XP443854A9282530|T0006                 |2023-10-01 13:42:16.000000 UTC|2023-10-01 13:42:16.000000 UTC|{"currency_code": "USD", "value": "135.05"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "4259.55"}  |{"currency_code": "USD", "value": "4259.55"}  |01                    |{"account_id": "5M2QMQLBLLR3G", "email_address": "albert.46222@gmail.com", "address_status": "Y", "payer_status": "N", "payer_name": {"alternate_full_name": "\u05d1\u05d9\u05ea \u05d4\u05de\u05e8\u05e4\u05d0"}, "country_code": "IL"}                               |{"name": "albert.aharonoff ", "address": {"line1": "Rabi tzadock 3/2", "city": "Beit shemesh", "country_code": "IL", "postal_code": "9908178"}}           |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "99.98"}, "item_amount": {"currency_code": "USD", "value": "99.98"}, "total_item_amount": {"currency_code": "USD", "value": "99.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}, {"item_name": "Gift For Loved One - Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "34.97"}, "item_amount": {"currency_code": "USD", "value": "34.97"}, "total_item_amount": {"currency_code": "USD", "value": "34.97"}}]}|{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |0VN42581100763232|T0006                 |2023-10-01 13:52:32.000000 UTC|2023-10-01 13:52:32.000000 UTC|{"currency_code": "USD", "value": "90.08"}    |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "4402.37"}  |{"currency_code": "USD", "value": "4402.37"}  |01                    |{"account_id": "EMMYR2RHCER5W", "email_address": "jbarreno062@gmail.com", "address_status": "Y", "payer_status": "N", "payer_name": {"given_name": "Jose", "surname": "Barreno", "alternate_full_name": "Jose Barreno"}, "country_code": "US"}                         |{"name": "Jose ", "address": {"line1": "2465 madera rd Pecos tx 79772", "city": "string:PECOS ", "country_code": "US", "postal_code": "79772"}}           |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "89.98"}, "item_amount": {"currency_code": "USD", "value": "89.98"}, "total_item_amount": {"currency_code": "USD", "value": "89.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}]}                                                                                                                                                                                                                                                                            |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |8YB176869A574353M|T0006                 |2023-10-01 14:18:15.000000 UTC|2023-10-01 14:18:15.000000 UTC|{"currency_code": "USD", "value": "135.05"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "5131.48"}  |{"currency_code": "USD", "value": "5131.48"}  |01                    |{"account_id": "ZTSZEDWYBX7KJ", "email_address": "loanswithmore@gmail.com", "address_status": "Y", "payer_status": "Y", "payer_name": {"given_name": "Shawn", "surname": "Hayes", "alternate_full_name": "Shawn Hayes"}, "country_code": "US"}                         |{"name": "Shawn Hayes", "address": {"line1": "26932 Hopkins", "city": "Inkster", "country_code": "US", "postal_code": "48141"}}                           |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "99.98"}, "item_amount": {"currency_code": "USD", "value": "99.98"}, "total_item_amount": {"currency_code": "USD", "value": "99.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}, {"item_name": "Gift For Loved One - Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "34.97"}, "item_amount": {"currency_code": "USD", "value": "34.97"}, "total_item_amount": {"currency_code": "USD", "value": "34.97"}}]}|{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |2C168720N9753073Y|T1106                 |2023-10-01 15:00:44.000000 UTC|2023-10-01 15:00:44.000000 UTC|{"currency_code": "USD", "value": "-99.98"}   |S                 |Reverse Payment for PP-R-CQI-497625896                                                                                         |{"currency_code": "USD", "value": "6279.55"}  |{"currency_code": "USD", "value": "6279.55"}  |02                    |{"account_id": "EFM8CNBM5VDVS", "email_address": "smoss84@gmail.com", "address_status": "N", "payer_status": "N", "payer_name": {"given_name": "Sandy", "surname": "Moss", "alternate_full_name": "Sandy Moss"}, "country_code": "US"}                                 |{"name": "Sandy, Moss"}                                                                                                                                   |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |15W74582AB350362E|T1106                 |2023-10-01 18:54:34.000000 UTC|2023-10-01 18:54:34.000000 UTC|{"currency_code": "USD", "value": "-100.00"}  |S                 |Reverse Payment for PP-R-BFQ-497655858                                                                                         |{"currency_code": "USD", "value": "9915.68"}  |{"currency_code": "USD", "value": "9915.68"}  |02                    |{"account_id": "XGQB7BAZTYYRW", "email_address": "youngjcy67@aol.com", "address_status": "N", "payer_status": "Y", "payer_name": {"given_name": "joseph", "surname": "young", "alternate_full_name": "joseph young"}, "country_code": "US"}                            |{"name": "joseph, young"}                                                                                                                                 |{"item_details": [{"item_name": "Buy 1 (40 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}, {"item_name": "Free eBook", "item_quantity": "1.000", "tax_percentage": "0"}, {"item_name": "Expedited Shipping", "item_quantity": "1.000", "tax_percentage": "0"}, {"item_name": "VitaGlow Citrus Collagen", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                   |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |1ND72366W8477854P|T1111                 |2023-09-10 19:21:57.000000 UTC|2023-10-01 19:21:41.000000 UTC|{"currency_code": "USD", "value": "104.81"}   |D                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "10297.97"} |{"currency_code": "USD", "value": "10297.97"} |02                    |{"account_id": "KZJFM8ZBBSJJ4", "email_address": "craig.tintown@gmail.com", "address_status": "N", "payer_status": "Y", "payer_name": {"given_name": "craig", "surname": "gates", "middle_name": "irvine", "alternate_full_name": "craig gates"}, "country_code": "CA"}|{"name": "craig, gates"}                                                                                                                                  |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1.000", "tax_percentage": "0"}, {"item_name": "Expedited Shipping", "item_quantity": "1.000", "tax_percentage": "0"}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# |4WR57206HJ375982R|T0006                 |2023-10-01 21:37:05.000000 UTC|2023-10-01 21:37:05.000000 UTC|{"currency_code": "USD", "value": "135.05"}   |S                 |NULL                                                                                                                           |{"currency_code": "USD", "value": "12894.58"} |{"currency_code": "USD", "value": "12894.58"} |01                    |{"account_id": "AYC4ZUF8264T8", "email_address": "rdl0201@gmail.com", "address_status": "Y", "payer_status": "N", "payer_name": {"given_name": "Rickey", "surname": "Lee", "alternate_full_name": "Rickey Lee"}, "country_code": "US"}                                 |{"name": "Rickey lee", "address": {"line1": "3127 greenfield rd lot 355", "city": "Pearl", "country_code": "US", "postal_code": "39208"}}                 |{"item_details": [{"item_name": "Buy 2 Get 1 Free (120 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "99.98"}, "item_amount": {"currency_code": "USD", "value": "99.98"}, "total_item_amount": {"currency_code": "USD", "value": "99.98"}}, {"item_name": "Free eBook", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "0.10"}, "item_amount": {"currency_code": "USD", "value": "0.10"}, "total_item_amount": {"currency_code": "USD", "value": "0.10"}}, {"item_name": "Gift For Loved One - Buy 1 (40 Servings)", "item_quantity": "1", "item_unit_price": {"currency_code": "USD", "value": "34.97"}, "item_amount": {"currency_code": "USD", "value": "34.97"}, "total_item_amount": {"currency_code": "USD", "value": "34.97"}}]}|{}        |{}          |{}            |2024-03-07 02:36:03.253095 UTC|2024-03-07|2   |2026-04-01 12:36:10.915|dispute_pp01.csv|5197630  |2026-04-01 01:49:46   |
# +-----------------+----------------------+------------------------------+------------------------------+----------------------------------------------+------------------+-------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+----------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+--------------+------------------------------+----------+----+-----------------------+----------------+---------+----------------------+
# only showing top 20 rows
# 2026-04-01 19:36:34 | INFO     | ETL | bronze_ingestion.py:149 | --------------------------------------------------------------------------------
# 2026-04-01 19:36:34 | INFO     | ETL | bronze_ingestion.py:66 | Starting Bronze ingestion for entity: Dispute_Transactions
# 2026-04-01 19:36:34 | INFO     | ETL | bronze_ingestion.py:74 | Uploading file: s3://01-paypal-analytics/dispute_transactions
# 2026-04-01 19:36:41 | INFO     | ETL | bronze_ingestion.py:94 | Dispute_Transactions: Schema inferred successfully
# 2026-04-01 19:36:56 | INFO     | ETL | bronze_ingestion.py:147 | Completed Bronze ingestion for entity: Dispute_Transactions
# +------------------+------------------------------+------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+--------+------------------------------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# ...
# |PP-R-SMN-501472024|2023-10-24 20:56:15.000000 UTC|2023-12-12 21:19:52.000000 UTC|[{"buyer_transaction_id": "6TP57245CP650013W", "seller_transaction_id": "8W996293G9777993W", "create_time": "2023-10-24T20:25:54.000Z", "transaction_status": "COMPLETED", "gross_amount": {"currency_code": "USD", "value": "54.96"}, "custom": "39392851", "buyer": {"name": "Nyeplu Kpodi"}, "seller": {"email": "precher92dl@gmail.com", "merchant_id": "FH5H4V4NAX59S", "name": "DUC LONG NGO"}, "items": [{"item_name": "Buy 1 (40 Servings)", "item_quantity": "1", "reason": "MERCHANDISE_OR_SERVICE_NOT_RECEIVED", "item_type": "PRODUCT"}], "seller_protection_eligible": true}]                                                                                                                                                                                                                                                                                  |MERCHANDISE_OR_SERVICE_NOT_RECEIVED    |RESOLVED|{"currency_code": "USD", "value": "54.96"}|RESOLVED     |{"outcome_code": "RESOLVED_BUYER_FAVOUR", "outcome_reason": "INVALID_DELIVERY_PROOF", "amount_refunded": {"currency_code": "USD", "value": "54.96"}}             |[{"type": "PAYOUT_TO_BUYER", "adjudication_time": "2023-10-24T20:57:36.865Z", "reason": "TRUSTED_BUYER_PAYOUT", "dispute_life_cycle_stage": "CHARGEBACK"},{"type": "RECOVER_FROM_SELLER", "adjudication_time": "2023-12-12T21:12:05.977Z", "reason": "INVALID_DELIVERY_PROOF", "dispute_life_cycle_stage": "CHARGEBACK"}]            |[{"affected_party": "BUYER", "amount": {"currency_code": "USD", "value": "54.96"}, "initiated_time": "2023-10-24T20:56:16.107Z", "type": "CREDIT", "reason": "DISPUTE_SETTLEMENT"},{"affected_party": "SELLER", "amount": {"currency_code": "USD", "value": "54.96"}, "initiated_time": "2023-12-12T21:18:08.054Z", "type": "DEBIT", "reason": "DISPUTE_SETTLEMENT"},{"affected_party": "SELLER", "amount": {"currency_code": "USD", "value": "8.00"}, "initiated_time": "2023-12-12T21:18:08.054Z", "type": "DEBIT", "reason": "DISPUTE_FEE"}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |CHARGEBACK              |INTERNAL       |{"merchant_contacted": false, "buyer_contacted_time": "2023-10-24T20:56:14.474Z", "merchandize_dispute_properties": {"issue_type": "PRODUCT"}}                                                                               |[{"evidence_type": "CREATE", "notes": "I just made one order of 1 item, but they added this items to my ordered and charged me, I want to get a full refund, I am unable to reach out to them ", "source": "SUBMITTED_BY_BUYER", "date": "2023-10-24T20:56:15.343Z", "dispute_life_cycle_stage": "CHARGEBACK"}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |PP-R-EMZ-502564408|2023-11-03 02:57:21.000000 UTC|2023-11-23 04:05:30.000000 UTC|[{"buyer_transaction_id": "93F993528X587732S", "seller_transaction_id": "6W751464B6615411B", "create_time": "2023-10-18T14:48:05.000Z", "transaction_status": "COMPLETED", "gross_amount": {"currency_code": "USD", "value": "54.96"}, "custom": "38934854", "buyer": {"name": "robert kruchten"}, "seller": {"email": "precher92dl@gmail.com", "merchant_id": "FH5H4V4NAX59S", "name": "DUC LONG NGO"}, "items": [{"item_name": "Buy 1 (40 Servings)", "item_description": "Buy 1 (40 Servings)", "item_quantity": "1", "reason": "MERCHANDISE_OR_SERVICE_NOT_RECEIVED", "item_type": "PRODUCT"}], "seller_protection_eligible": true, "seller_protection_type": "EXPANDED_SELLER_PROTECTION"}]                                                                                                                                                                            |MERCHANDISE_OR_SERVICE_NOT_RECEIVED    |RESOLVED|{"currency_code": "USD", "value": "54.96"}|RESOLVED     |{"outcome_code": "RESOLVED_SELLER_FAVOUR", "outcome_reason": "INELIGIBLE_BUYER_PROTECTION_POLICY"}                                                               |[]                                                                                                                                                                                                                                                                                                                                   |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |INQUIRY                 |INTERNAL       |{"merchant_contacted": false, "buyer_contacted_time": "2023-11-03T02:57:21.617Z"}                                                                                                                                            |[{"evidence_type": "CREATE", "notes": "Tried tracking nothing happens. Pretty sure its a scam", "source": "SUBMITTED_BY_BUYER", "date": "2023-11-03T02:57:21.964Z", "dispute_life_cycle_stage": "INQUIRY"}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +------------------+------------------------------+------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+--------+------------------------------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# only showing top 20 rows
# 2026-04-01 19:36:58 | INFO     | ETL | bronze_ingestion.py:149 | --------------------------------------------------------------------------------
# 2026-04-01 19:36:58 | INFO     | ETL | bronze_ingestion.py:153 | Bronze ingestion completed.

# %%
app.stop()
# Out:
# 2026-04-01 19:37:01 | INFO     | ETL | platform_app.py:259 | Stopping Spark session...
# 2026-04-01 19:37:02 | INFO     | ETL | platform_app.py:261 | Spark stopped.
